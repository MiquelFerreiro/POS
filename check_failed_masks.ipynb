# %%
base_path_video = "BVPs"

paths = [
    "Q1_1",
    "Q1_2",
    "Q2_1",
    "Q2_2",
    "Q3_1",
    "Q3_2",
    "Q4_1",
    "Q4_2",
    "Q5_1",
    "Q5_2",
    "Q6_1",
    "Q6_2",
    "Q7_1",
    "Q7_2",
    "Q8_1",
    "Q8_2",
    "Q9_1",
    "Q9_2"
]

patients = list(range(1, 59))

# %%
import numpy as np

# %%
for patient in patients:
    for path in paths:
        try:
            bvp = np.load(f"{base_path_video}/Patient_{patient}/{path}.npy")
        except Exception as e:
            print(f"Error: Patient{patient} - {path}: {e}")
# Out:
# Error: Patient16 - Q3_1: [Errno 2] No such file or directory: 'BVPs/Patient_16/Q3_1.npy'
# Error: Patient23 - Q1_1: [Errno 2] No such file or directory: 'BVPs/Patient_23/Q1_1.npy'
# Error: Patient23 - Q1_2: [Errno 2] No such file or directory: 'BVPs/Patient_23/Q1_2.npy'
# Error: Patient23 - Q2_1: [Errno 2] No such file or directory: 'BVPs/Patient_23/Q2_1.npy'
# Error: Patient23 - Q2_2: [Errno 2] No such file or directory: 'BVPs/Patient_23/Q2_2.npy'
# Error: Patient23 - Q3_1: [Errno 2] No such file or directory: 'BVPs/Patient_23/Q3_1.npy'
# Error: Patient23 - Q3_2: [Errno 2] No such file or directory: 'BVPs/Patient_23/Q3_2.npy'
# Error: Patient23 - Q4_1: [Errno 2] No such file or directory: 'BVPs/Patient_23/Q4_1.npy'
# Error: Patient23 - Q4_2: [Errno 2] No such file or directory: 'BVPs/Patient_23/Q4_2.npy'
# Error: Patient23 - Q5_1: [Errno 2] No such file or directory: 'BVPs/Patient_23/Q5_1.npy'
# ...

# %%
for patient in patients:
    for path in paths:
        try:
            bvp = np.load(f"{base_path_video}/Patient_{patient}/{path}.npy")
            if (bvp.shape == ()):
                print(f"Patient_{patient} - {path}:")
        except Exception as e:
            print()
# Out:
# Patient_2 - Q1_1:
# Patient_11 - Q6_1:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Patient_52 - Q7_2:
# Patient_53 - Q4_2:

# %%
bvp = np.load(f"{base_path_video}/Patient_{11}/Q6_1.npy")

print(bvp.shape)
# Out:
# ()

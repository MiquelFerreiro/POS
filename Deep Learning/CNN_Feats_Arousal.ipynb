# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class BVP:
    def __init__(self, patient, quadrant, signal, features, id):
        self.patient = patient
        self.quadrant = quadrant
        self.signal = signal
        self.features = features
        self.id = id

MAX_VID_LENGTH = 100

# %%
patients = list(range(1, 62))
patients.remove(23)

quadrants = [
    "Q1_1",
    "Q1_2",
    "Q2_1",
    "Q2_2",
    "Q3_1",
    "Q3_2",
    "Q4_1",
    "Q4_2",
    "Q5_1",
    "Q5_2",
    "Q6_1",
    "Q6_2",
    "Q7_1",
    "Q7_2",
    "Q8_1",
    "Q8_2",
    "Q9_1",
    "Q9_2"
]

# %%
bvp_path = "../BVPs"

failed_masks = [
    [2, "Q1_1"],
    [9, "Q7_2"],
    [12, "Q4_1"],
    [14, "Q1_2"],
    [52, "Q7_2"],
    [53, "Q4_2"],
    [60, "Q3_2"]
]

# %%
def cut_bvp(bvp, t_start, t_end, fs=60):
    n = len(bvp)

    # Convert time to sample indices
    n_start = int(t_start * fs)
    n_end = int(t_end * fs)

    # Clamp to valid range
    n_start = max(0, min(n_start, n))
    n_end = max(0, min(n_end, n))

    return bvp[n_start:n_end]

# %%
def cut_relevant_bvp(data, quadrant, fs=60):

    if quadrant == "Q1_2":

        data = cut_bvp(data, 20, MAX_VID_LENGTH, fs)

    elif quadrant == "Q3_2":

        data = cut_bvp(data, 38, MAX_VID_LENGTH, fs)
    
    return data

# %%
BVPs = []

fs = 60

for patient in patients:

    for quadrant in quadrants:

        if [patient, quadrant] in failed_masks:
            print(f"Skipping Patient_{patient}, {quadrant}")
            continue

        data = np.load(f"{bvp_path}/Patient_{patient}/{quadrant}.npy")

        data = cut_relevant_bvp(data, quadrant, fs)

        id = f"{patient}{quadrant}"

        bvp = BVP(patient, quadrant, data, [], id)

        BVPs.append(bvp)

        #print(f"Patient_{patient}, {quadrant}: {data.shape}")

print(f"Loaded {len(BVPs)} BVP signals")
# Out:
# Skipping Patient_2, Q1_1
# Skipping Patient_9, Q7_2
# Skipping Patient_12, Q4_1
# Skipping Patient_14, Q1_2
# Skipping Patient_52, Q7_2
# Skipping Patient_53, Q4_2
# Skipping Patient_60, Q3_2
# Loaded 1073 BVP signals

# %%
from scipy.signal import find_peaks, czt

# %%
def compute_bvp_features_article(bvp_signal, fs, patient=None, quadrant=None):
    """
    Compute PPG features (14 features from paper) using CZT.
    Includes debug prints when something fails.
    """

    bvp = np.asarray(bvp_signal)

    if len(bvp) < fs * 2:
        print(f"[SHORT SIGNAL] Patient {patient}, {quadrant}")
        return None

    # ---- Remove DC ----
    bvp = bvp - np.mean(bvp)

    features = {}

    # --------------------------------------------------
    # 1. Peak detection → RR intervals
    # --------------------------------------------------
    min_dist = int(0.4 * fs)
    peaks, _ = find_peaks(bvp, distance=min_dist)

    if len(peaks) < 3:
        print(f"[PEAK DETECTION FAILED] Patient {patient}, {quadrant}")
        return None

    rr = np.diff(peaks) / fs
    hr = 60.0 / rr

    # --------------------------------------------------
    # 2. HR features
    # --------------------------------------------------
    features["hr_mean"] = np.mean(hr)
    features["hr_std"] = np.std(hr)

    # --------------------------------------------------
    # 3. HRV time-domain features
    # --------------------------------------------------
    features["rr_mean"] = np.mean(rr)
    features["rr_std"] = np.std(rr)

    diff_rr = np.diff(rr)

    if len(diff_rr) > 0:
        features["rmssd"] = np.sqrt(np.mean(diff_rr ** 2))
        features["sdsd"] = np.std(diff_rr)
        features["pnn50"] = np.sum(np.abs(diff_rr) > 0.05) / len(diff_rr)
    else:
        print(f"[RR DIFFERENCES FAILED] Patient {patient}, {quadrant}")
        features["rmssd"] = np.nan
        features["sdsd"] = np.nan
        features["pnn50"] = np.nan

    # --------------------------------------------------
    # 4. TINN
    # --------------------------------------------------
    try:
        hist, bin_edges = np.histogram(rr, bins=20)
        features["tinn"] = bin_edges[-1] - bin_edges[0]
    except Exception:
        print(f"[TINN FAILED] Patient {patient}, {quadrant}")
        features["tinn"] = np.nan

    # --------------------------------------------------
    # 5. Poincaré
    # --------------------------------------------------
    try:
        if len(diff_rr) > 0:
            sd1 = np.sqrt(np.var(diff_rr) / 2)
            sd2 = np.sqrt(2 * np.var(rr) - 0.5 * np.var(diff_rr))

            features["sd1"] = sd1
            features["sd2"] = sd2
            features["sd1_sd2"] = sd1 / sd2 if sd2 != 0 else np.nan
        else:
            raise ValueError
    except Exception:
        print(f"[POINCARE FAILED] Patient {patient}, {quadrant}")
        features["sd1"] = np.nan
        features["sd2"] = np.nan
        features["sd1_sd2"] = np.nan

    # --------------------------------------------------
    # 6. LF / HF using CZT
    # --------------------------------------------------
    try:
        rr_times = np.cumsum(rr)
        rr_times = np.insert(rr_times, 0, 0)

        fs_interp = 4.0
        t_uniform = np.arange(0, rr_times[-1], 1 / fs_interp)

        rr_interp = np.interp(
            t_uniform,
            rr_times,
            np.append(rr, rr[-1])
        )

        fmin = 0.04
        fmax = 0.4
        n_bins = 256

        w = np.exp(-1j * 2 * np.pi * (fmax - fmin) / (n_bins * fs_interp))
        a = np.exp(1j * 2 * np.pi * fmin / fs_interp)

        spectrum = czt(rr_interp, n_bins, w, a)
        power = np.abs(spectrum) ** 2
        freqs = np.linspace(fmin, fmax, n_bins)

        lf_band = (freqs >= 0.04) & (freqs < 0.15)
        hf_band = (freqs >= 0.15) & (freqs < 0.4)

        lf = np.sum(power[lf_band])
        hf = np.sum(power[hf_band])

        features["lf"] = lf
        features["hf"] = hf
        features["lf_hf"] = lf / hf if hf > 0 else np.nan

    except Exception:
        print(f"[LF/HF FAILED] Patient {patient}, {quadrant}")
        features["lf"] = np.nan
        features["hf"] = np.nan
        features["lf_hf"] = np.nan

    return features

# %%
bvp = BVPs[2]
fs = 60

features = compute_bvp_features_article(bvp.signal, fs, bvp.patient, bvp.quadrant)

# %%
print(bvp.patient, bvp.quadrant)
print(features)
# Out:
# 1 Q2_1
# {'hr_mean': 100.53924015095781, 'hr_std': 34.28763822791599, 'rr_mean': 0.6719298245614036, 'rr_std': 0.22313026236660477, 'rmssd': 0.27916222455598755, 'sdsd': 0.27909225198677157, 'pnn50': 0.6607142857142857, 'tinn': 0.5666666666666667, 'sd1': 0.19734802395647086, 'sd2': 0.2462275074155119, 'sd1_sd2': 0.8014865033882819, 'lf': 7305.553035238854, 'hf': 5825.711057788672, 'lf_hf': 1.254019116768881}

# %%
valid = []
failed = []

for bvp in BVPs:  # use a copy to safely remove items

    print(f"Computing Features for Patient_{bvp.patient}...", end="\r", flush=True)
    
    try:
        # Use the new windowed feature extraction
        feats = compute_bvp_features_article(bvp.signal, fs, bvp.patient, bvp.quadrant)

        if feats is None or feats == []:
            print(f"Failed: Patient_{bvp.patient}, {bvp.quadrant}")
            failed.append(f"Patient_{bvp.patient}, {bvp.quadrant}")
            BVPs.remove(bvp)  # remove problematic signal
        else:
            bvp.features = feats
            valid.append(f"Patient_{bvp.patient}, {bvp.quadrant}")

    except Exception as e:
        print(f"Error for Patient_{bvp.patient}, {bvp.quadrant}: {e}")
        failed.append(f"Patient_{bvp.patient}, {bvp.quadrant}")
        BVPs.remove(bvp)

print(f"Extracted features for {len(valid)} videos")
print(f"Failed: {failed}")
# Out:
# Extracted features for 1073 videos..
# Failed: []

# %%
print(failed)
# Out:
# []

# %%
for bvp in BVPs:

    try:

        if (f"Patient_{bvp.patient}, {bvp.quadrant}") not in failed:
            feats = bvp.features
            #print(bvp.patient, bvp.quadrant)
            for jdx in range(0, 14):
                dummie =  list(feats.values())[jdx] == np.nan

    except Exception as e:

        print(f"Not loaded on Patient_{bvp.patient}, {bvp.quadrant}")

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.feature_selection import SelectFpr, f_classif

# %%
# AROUSAL

def get_label_arousal(path):
    q = path.split("_")[0]

    if q in ["Q1", "Q2", "Q3"]:
        return "High Arousal"
    
    if q in ["Q4", "Q5", "Q6"]:
        return "Neutral Arousal"
    
    else:
        return "Low Arousal"
    
# VALENCE

def get_label_valence(path):
    q = path.split("_")[0]

    if q in ["Q1", "Q4", "Q7"]:
        return "Negative Valence"
    
    if q in ["Q2", "Q5", "Q8"]:
        return "Neutral Valence"
    
    else:
        return "Positive Valence"

# %%
X = []
y = []
groups = []

for bvp in BVPs:
    if bvp is None or bvp.features == []:
        print("Error: Patient", bvp.patient, bvp.quadrant)
        continue
    
    feat_values = list(bvp.features.values())
    X.append(feat_values)
    y.append(get_label_valence(bvp.quadrant))
    groups.append(bvp.id)  
    

X = np.array(X)
y = np.array(y)

print(X.shape, y.shape)
print(np.unique(y, return_counts=True))
print("Example of data: ", X[0])
# Out:
# (1073, 14) (1073,)
# (array(['Negative Valence', 'Neutral Valence', 'Positive Valence'],
#       dtype='<U16'), array([354, 360, 359], dtype=int64))
# Example of data:  [9.26717515e+01 2.87402265e+01 7.03645833e-01 1.83746427e-01
#  2.14400891e-01 2.14333471e-01 7.41935484e-01 5.66666667e-01
#  1.51556651e-01 2.11083113e-01 7.17995147e-01 5.94819513e+03
#  3.30514666e+03 1.79967661e+00]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(y)

# %%
import tensorflow as tf

layers = tf.keras.layers
models = tf.keras.models

model = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X.shape[1],)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(32, activation='relu'),
    layers.Dropout(0.3),

    layers.Dense(3, activation='softmax')  # ✅ multiclass
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# c:\Users\mique\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from sklearn.model_selection import GroupKFold

gkf = GroupKFold(n_splits=5)

for fold, (train_idx, test_idx) in enumerate(gkf.split(X, y, groups)):
    print(f"Fold {fold}")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # Fit scaler ONLY on train
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    model = tf.keras.models.clone_model(model)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=30,
        batch_size=32,
        verbose=1
    )
# Out:
# Fold 0
# Epoch 1/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3608 - loss: 1.5754 - val_accuracy: 0.3488 - val_loss: 1.0840
# Epoch 2/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4000 - loss: 1.2833 - val_accuracy: 0.3628 - val_loss: 1.0770
# Epoch 3/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4005 - loss: 1.2520 - val_accuracy: 0.3907 - val_loss: 1.0701
# Epoch 4/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3827 - loss: 1.2470 - val_accuracy: 0.4465 - val_loss: 1.0621
# Epoch 5/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3984 - loss: 1.1856 - val_accuracy: 0.4140 - val_loss: 1.0583
# Epoch 6/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4694 - loss: 1.0888 - val_accuracy: 0.3860 - val_loss: 1.0507
# Epoch 7/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4503 - loss: 1.1071 - val_accuracy: 0.4093 - val_loss: 1.0441
# Epoch 8/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4193 - loss: 1.1186 - val_accuracy: 0.4279 - val_loss: 1.0424
# Epoch 9/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4182 - loss: 1.1083 - val_accuracy: 0.4419 - val_loss: 1.0377
# Epoch 10/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4692 - loss: 1.0493 - val_accuracy: 0.4419 - val_loss: 1.0365
# Epoch 11/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4177 - loss: 1.1078 - val_accuracy: 0.4326 - val_loss: 1.0315
# Epoch 12/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4424 - loss: 1.0856 - val_accuracy: 0.4419 - val_loss: 1.0205
# Epoch 13/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4221 - loss: 1.0892 - val_accuracy: 0.4279 - val_loss: 1.0170
# Epoch 14/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4640 - loss: 1.0722 - val_accuracy: 0.4372 - val_loss: 1.0129
# Epoch 15/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4450 - loss: 1.0859 - val_accuracy: 0.4465 - val_loss: 1.0078
# Epoch 16/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4848 - loss: 1.0341 - val_accuracy: 0.4465 - val_loss: 1.0048
# Epoch 17/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4345 - loss: 1.0915 - val_accuracy: 0.4465 - val_loss: 1.0041
# Epoch 18/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4645 - loss: 1.0264 - val_accuracy: 0.4419 - val_loss: 1.0045
# Epoch 19/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4309 - loss: 1.0466 - val_accuracy: 0.4512 - val_loss: 1.0010
# Epoch 20/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4536 - loss: 1.0308 - val_accuracy: 0.4512 - val_loss: 0.9969
# Epoch 21/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4654 - loss: 1.0301 - val_accuracy: 0.4651 - val_loss: 0.9885
# Epoch 22/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4721 - loss: 1.0305 - val_accuracy: 0.4698 - val_loss: 0.9904
# Epoch 23/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4648 - loss: 1.0245 - val_accuracy: 0.4744 - val_loss: 0.9903
# Epoch 24/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4738 - loss: 1.0067 - val_accuracy: 0.4744 - val_loss: 0.9892
# Epoch 25/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4781 - loss: 1.0291 - val_accuracy: 0.4744 - val_loss: 0.9910
# Epoch 26/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5101 - loss: 0.9924 - val_accuracy: 0.4791 - val_loss: 0.9881
# Epoch 27/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4679 - loss: 1.0327 - val_accuracy: 0.4698 - val_loss: 0.9917
# Epoch 28/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4565 - loss: 0.9998 - val_accuracy: 0.4837 - val_loss: 0.9906
# Epoch 29/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4872 - loss: 0.9982 - val_accuracy: 0.4698 - val_loss: 0.9900
# Epoch 30/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4747 - loss: 1.0212 - val_accuracy: 0.4698 - val_loss: 0.9899
# Fold 1
# Epoch 1/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3746 - loss: 1.5652 - val_accuracy: 0.3535 - val_loss: 1.0966
# Epoch 2/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4377 - loss: 1.2712 - val_accuracy: 0.3674 - val_loss: 1.0897
# Epoch 3/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3772 - loss: 1.2416 - val_accuracy: 0.3953 - val_loss: 1.0831
# Epoch 4/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3846 - loss: 1.2400 - val_accuracy: 0.3767 - val_loss: 1.0754
# Epoch 5/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3917 - loss: 1.1914 - val_accuracy: 0.3953 - val_loss: 1.0748
# Epoch 6/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4312 - loss: 1.1314 - val_accuracy: 0.3860 - val_loss: 1.0719
# Epoch 7/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3908 - loss: 1.1446 - val_accuracy: 0.3860 - val_loss: 1.0591
# Epoch 8/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4607 - loss: 1.0839 - val_accuracy: 0.3674 - val_loss: 1.0570
# Epoch 9/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4036 - loss: 1.0885 - val_accuracy: 0.4326 - val_loss: 1.0499
# Epoch 10/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4366 - loss: 1.0742 - val_accuracy: 0.4419 - val_loss: 1.0491
# Epoch 11/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4293 - loss: 1.0466 - val_accuracy: 0.4419 - val_loss: 1.0428
# Epoch 12/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4728 - loss: 1.0586 - val_accuracy: 0.4140 - val_loss: 1.0455
# Epoch 13/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4569 - loss: 1.0282 - val_accuracy: 0.4279 - val_loss: 1.0425
# Epoch 14/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4315 - loss: 1.0611 - val_accuracy: 0.4372 - val_loss: 1.0385
# Epoch 15/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5037 - loss: 1.0112 - val_accuracy: 0.4233 - val_loss: 1.0399
# Epoch 16/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4694 - loss: 1.0343 - val_accuracy: 0.4233 - val_loss: 1.0324
# Epoch 17/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4760 - loss: 1.0489 - val_accuracy: 0.4326 - val_loss: 1.0258
# Epoch 18/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4602 - loss: 1.0115 - val_accuracy: 0.4279 - val_loss: 1.0229
# Epoch 19/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5111 - loss: 1.0099 - val_accuracy: 0.3953 - val_loss: 1.0311
# Epoch 20/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4814 - loss: 1.0207 - val_accuracy: 0.4093 - val_loss: 1.0345
# Epoch 21/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4713 - loss: 1.0085 - val_accuracy: 0.4186 - val_loss: 1.0363
# Epoch 22/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4630 - loss: 1.0482 - val_accuracy: 0.4186 - val_loss: 1.0356
# Epoch 23/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4693 - loss: 0.9986 - val_accuracy: 0.4093 - val_loss: 1.0296
# Epoch 24/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4828 - loss: 1.0200 - val_accuracy: 0.4372 - val_loss: 1.0301
# Epoch 25/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4718 - loss: 1.0057 - val_accuracy: 0.4605 - val_loss: 1.0317
# Epoch 26/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4648 - loss: 1.0207 - val_accuracy: 0.4558 - val_loss: 1.0267
# Epoch 27/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5434 - loss: 0.9791 - val_accuracy: 0.4465 - val_loss: 1.0299
# Epoch 28/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4809 - loss: 1.0039 - val_accuracy: 0.4512 - val_loss: 1.0291
# Epoch 29/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4465 - loss: 1.0072 - val_accuracy: 0.4326 - val_loss: 1.0324
# Epoch 30/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4782 - loss: 0.9785 - val_accuracy: 0.4884 - val_loss: 1.0314
# Fold 2
# Epoch 1/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3686 - loss: 1.4959 - val_accuracy: 0.3395 - val_loss: 1.0785
# Epoch 2/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3873 - loss: 1.2699 - val_accuracy: 0.3721 - val_loss: 1.0581
# Epoch 3/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3772 - loss: 1.2545 - val_accuracy: 0.4605 - val_loss: 1.0442
# Epoch 4/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4205 - loss: 1.1605 - val_accuracy: 0.4558 - val_loss: 1.0431
# Epoch 5/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3917 - loss: 1.1532 - val_accuracy: 0.4465 - val_loss: 1.0438
# Epoch 6/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3851 - loss: 1.1523 - val_accuracy: 0.4558 - val_loss: 1.0412
# Epoch 7/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4344 - loss: 1.1122 - val_accuracy: 0.4605 - val_loss: 1.0386
# Epoch 8/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3905 - loss: 1.1318 - val_accuracy: 0.4651 - val_loss: 1.0364
# Epoch 9/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3871 - loss: 1.1052 - val_accuracy: 0.4698 - val_loss: 1.0415
# Epoch 10/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3978 - loss: 1.1151 - val_accuracy: 0.4512 - val_loss: 1.0389
# Epoch 11/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4836 - loss: 1.0474 - val_accuracy: 0.4744 - val_loss: 1.0347
# Epoch 12/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4258 - loss: 1.0718 - val_accuracy: 0.4558 - val_loss: 1.0334
# Epoch 13/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4399 - loss: 1.0406 - val_accuracy: 0.4698 - val_loss: 1.0357
# Epoch 14/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4551 - loss: 1.0602 - val_accuracy: 0.4698 - val_loss: 1.0358
# Epoch 15/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4099 - loss: 1.0483 - val_accuracy: 0.4698 - val_loss: 1.0361
# Epoch 16/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4400 - loss: 1.0460 - val_accuracy: 0.4744 - val_loss: 1.0334
# Epoch 17/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4726 - loss: 1.0490 - val_accuracy: 0.4512 - val_loss: 1.0335
# Epoch 18/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4481 - loss: 1.0701 - val_accuracy: 0.4558 - val_loss: 1.0355
# Epoch 19/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4442 - loss: 1.0470 - val_accuracy: 0.4605 - val_loss: 1.0287
# Epoch 20/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4756 - loss: 1.0302 - val_accuracy: 0.4744 - val_loss: 1.0153
# Epoch 21/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4351 - loss: 1.0420 - val_accuracy: 0.4651 - val_loss: 1.0237
# Epoch 22/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4648 - loss: 1.0330 - val_accuracy: 0.4837 - val_loss: 1.0226
# Epoch 23/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4399 - loss: 1.0334 - val_accuracy: 0.4837 - val_loss: 1.0184
# Epoch 24/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4688 - loss: 1.0292 - val_accuracy: 0.4698 - val_loss: 1.0141
# Epoch 25/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4619 - loss: 1.0280 - val_accuracy: 0.4977 - val_loss: 1.0206
# Epoch 26/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4460 - loss: 1.0307 - val_accuracy: 0.4837 - val_loss: 1.0209
# Epoch 27/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5148 - loss: 0.9924 - val_accuracy: 0.4698 - val_loss: 1.0278
# Epoch 28/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4922 - loss: 0.9855 - val_accuracy: 0.4558 - val_loss: 1.0281
# Epoch 29/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4749 - loss: 1.0067 - val_accuracy: 0.5023 - val_loss: 1.0248
# Epoch 30/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5007 - loss: 0.9847 - val_accuracy: 0.4698 - val_loss: 1.0223
# Fold 3
# Epoch 1/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2953 - loss: 1.8805 - val_accuracy: 0.3084 - val_loss: 1.1354
# Epoch 2/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3313 - loss: 1.4110 - val_accuracy: 0.3551 - val_loss: 1.1112
# Epoch 3/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3731 - loss: 1.2517 - val_accuracy: 0.3318 - val_loss: 1.1198
# Epoch 4/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3418 - loss: 1.2590 - val_accuracy: 0.3692 - val_loss: 1.1062
# Epoch 5/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3806 - loss: 1.2007 - val_accuracy: 0.3458 - val_loss: 1.1000
# Epoch 6/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4184 - loss: 1.1575 - val_accuracy: 0.4065 - val_loss: 1.0889
# Epoch 7/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3650 - loss: 1.1836 - val_accuracy: 0.4159 - val_loss: 1.0794
# Epoch 8/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4072 - loss: 1.1161 - val_accuracy: 0.3925 - val_loss: 1.0822
# Epoch 9/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4060 - loss: 1.1120 - val_accuracy: 0.3738 - val_loss: 1.0758
# Epoch 10/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4385 - loss: 1.0671 - val_accuracy: 0.4112 - val_loss: 1.0795
# Epoch 11/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4552 - loss: 1.0552 - val_accuracy: 0.3738 - val_loss: 1.0799
# Epoch 12/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4302 - loss: 1.0757 - val_accuracy: 0.3551 - val_loss: 1.0901
# Epoch 13/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4730 - loss: 1.0540 - val_accuracy: 0.3785 - val_loss: 1.0795
# Epoch 14/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4518 - loss: 1.0709 - val_accuracy: 0.3972 - val_loss: 1.0695
# Epoch 15/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4681 - loss: 1.0314 - val_accuracy: 0.4019 - val_loss: 1.0683
# Epoch 16/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4607 - loss: 1.0359 - val_accuracy: 0.4019 - val_loss: 1.0741
# Epoch 17/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4534 - loss: 1.0474 - val_accuracy: 0.4393 - val_loss: 1.0658
# Epoch 18/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4957 - loss: 1.0268 - val_accuracy: 0.4346 - val_loss: 1.0672
# Epoch 19/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4756 - loss: 1.0395 - val_accuracy: 0.4252 - val_loss: 1.0656
# Epoch 20/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4255 - loss: 1.0824 - val_accuracy: 0.4252 - val_loss: 1.0712
# Epoch 21/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4788 - loss: 1.0134 - val_accuracy: 0.4439 - val_loss: 1.0663
# Epoch 22/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4481 - loss: 1.0210 - val_accuracy: 0.4299 - val_loss: 1.0649
# Epoch 23/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4787 - loss: 0.9925 - val_accuracy: 0.4439 - val_loss: 1.0607
# Epoch 24/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4538 - loss: 1.0345 - val_accuracy: 0.4439 - val_loss: 1.0613
# Epoch 25/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4497 - loss: 1.0329 - val_accuracy: 0.4299 - val_loss: 1.0545
# Epoch 26/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4694 - loss: 1.0280 - val_accuracy: 0.4533 - val_loss: 1.0585
# Epoch 27/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4919 - loss: 1.0080 - val_accuracy: 0.4252 - val_loss: 1.0598
# Epoch 28/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4830 - loss: 1.0128 - val_accuracy: 0.4159 - val_loss: 1.0616
# Epoch 29/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4734 - loss: 1.0293 - val_accuracy: 0.4533 - val_loss: 1.0605
# Epoch 30/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5009 - loss: 0.9941 - val_accuracy: 0.4299 - val_loss: 1.0520
# Fold 4
# Epoch 1/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3775 - loss: 1.4683 - val_accuracy: 0.3505 - val_loss: 1.0982
# Epoch 2/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3671 - loss: 1.2369 - val_accuracy: 0.3364 - val_loss: 1.0864
# Epoch 3/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3876 - loss: 1.2099 - val_accuracy: 0.3271 - val_loss: 1.0836
# Epoch 4/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4092 - loss: 1.1408 - val_accuracy: 0.3738 - val_loss: 1.0729
# Epoch 5/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4460 - loss: 1.1009 - val_accuracy: 0.3832 - val_loss: 1.0713
# Epoch 6/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4317 - loss: 1.1452 - val_accuracy: 0.3738 - val_loss: 1.0732
# Epoch 7/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4537 - loss: 1.1061 - val_accuracy: 0.3832 - val_loss: 1.0799
# Epoch 8/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4403 - loss: 1.0901 - val_accuracy: 0.3972 - val_loss: 1.0698
# Epoch 9/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4694 - loss: 1.0617 - val_accuracy: 0.4065 - val_loss: 1.0654
# Epoch 10/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4729 - loss: 1.0367 - val_accuracy: 0.4019 - val_loss: 1.0682
# Epoch 11/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4022 - loss: 1.1082 - val_accuracy: 0.4065 - val_loss: 1.0594
# Epoch 12/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4390 - loss: 1.0632 - val_accuracy: 0.4065 - val_loss: 1.0549
# Epoch 13/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4643 - loss: 1.0329 - val_accuracy: 0.4159 - val_loss: 1.0568
# Epoch 14/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4790 - loss: 1.0447 - val_accuracy: 0.4159 - val_loss: 1.0480
# Epoch 15/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4857 - loss: 1.0269 - val_accuracy: 0.4252 - val_loss: 1.0466
# Epoch 16/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4709 - loss: 1.0502 - val_accuracy: 0.4252 - val_loss: 1.0451
# Epoch 17/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4564 - loss: 1.0308 - val_accuracy: 0.3972 - val_loss: 1.0511
# Epoch 18/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4652 - loss: 1.0342 - val_accuracy: 0.4439 - val_loss: 1.0437
# Epoch 19/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4742 - loss: 1.0387 - val_accuracy: 0.4346 - val_loss: 1.0471
# Epoch 20/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4704 - loss: 1.0042 - val_accuracy: 0.4252 - val_loss: 1.0464
# Epoch 21/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4896 - loss: 1.0103 - val_accuracy: 0.4252 - val_loss: 1.0478
# Epoch 22/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4703 - loss: 1.0163 - val_accuracy: 0.4393 - val_loss: 1.0475
# Epoch 23/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4648 - loss: 0.9973 - val_accuracy: 0.4393 - val_loss: 1.0460
# Epoch 24/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4333 - loss: 1.0297 - val_accuracy: 0.4206 - val_loss: 1.0426
# Epoch 25/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4977 - loss: 1.0074 - val_accuracy: 0.4299 - val_loss: 1.0462
# Epoch 26/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4886 - loss: 1.0014 - val_accuracy: 0.4439 - val_loss: 1.0447
# Epoch 27/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4626 - loss: 1.0074 - val_accuracy: 0.4299 - val_loss: 1.0442
# Epoch 28/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4865 - loss: 1.0092 - val_accuracy: 0.4299 - val_loss: 1.0467
# Epoch 29/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4927 - loss: 1.0057 - val_accuracy: 0.4346 - val_loss: 1.0458
# Epoch 30/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4601 - loss: 1.0062 - val_accuracy: 0.4439 - val_loss: 1.0352

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)

print(classification_report(y_test, y_pred))

print(confusion_matrix(y_test, y_pred))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#               precision    recall  f1-score   support
#
#            0       0.39      0.41      0.40        68
#            1       0.52      0.74      0.61        77
#            2       0.30      0.14      0.20        69
#
#     accuracy                           0.44       214
#    macro avg       0.41      0.43      0.40       214
# weighted avg       0.41      0.44      0.41       214
#
# [[28 26 14]
#  [11 57  9]
#  [32 27 10]]

# %%
import numpy as np
import matplotlib.pyplot as plt

from Modeling_CUT import getmodelresults

# %%
def get_timestamp(center, window_size):
    return [center - window_size/2, center + window_size/2]

# %%
def create_timestamps(window_sizes):

    class Timestamps:
        Q1_1 = [get_timestamp(12, window_sizes[1, 1])]
        Q1_2 = [get_timestamp(26, window_sizes[1, 2])]

        # Q1_1 = [get_timestamp(10, window_sizes[1, 1])]
        # Q1_2 = [get_timestamp(24, window_sizes[1, 2])]

        Q2_1 = [get_timestamp(6, window_sizes[2, 1])]
        Q2_2 = [get_timestamp(12, window_sizes[2, 2])]

        Q3_1 = [get_timestamp(19, window_sizes[3, 1])]
        Q3_2 = [get_timestamp(40, window_sizes[3, 2])]

        Q4_1 = [get_timestamp(15, window_sizes[4, 1])]
        Q4_2 = [get_timestamp(15, window_sizes[4, 2])]

        Q5_1 = [get_timestamp(15, window_sizes[5, 1])]
        Q5_2 = [get_timestamp(10, window_sizes[5, 2])]

        Q6_1 = [get_timestamp(84, window_sizes[6, 1])]
        Q6_2 = [get_timestamp(15, window_sizes[6, 2])]

        Q7_1 = [get_timestamp(40, window_sizes[7, 1])]
        Q7_2 = [get_timestamp(40, window_sizes[7, 2])]
        
        Q8_1 = [get_timestamp(15, window_sizes[8, 1])]
        Q8_2 = [get_timestamp(12, window_sizes[8, 2])]

        Q9_1 = [get_timestamp(15, window_sizes[9, 1])]
        Q9_2 = [get_timestamp(15, window_sizes[9, 2])]

    return Timestamps

# %%
results = []

# %%
common_window_size = 2
window_sizes = np.ones((9, 2))*common_window_size

# common_window_size = 5
# window_sizes = np.ones((9, 2))*5
# window_sizes[0:2][:] = 3

print(window_sizes)

window_sizes = np.pad(window_sizes, ((1, 0), (1, 0)), mode='constant')

#print(window_sizes)
# Out:
# [[2. 2.]
#  [2. 2.]
#  [2. 2.]
#  [2. 2.]
#  [2. 2.]
#  [2. 2.]
#  [2. 2.]
#  [2. 2.]
#  [2. 2.]]

# %%
quadrants_all = [
    "Q1_1",
    "Q1_2",
    "Q2_1",
    "Q2_2",
    "Q3_1",
    "Q3_2",
    "Q4_1",
    "Q4_2",
    "Q5_1",
    "Q5_2",
    "Q6_1",
    "Q6_2",
    "Q7_1",
    "Q7_2",
    "Q8_1",
    "Q8_2",
    "Q9_1",
    "Q9_2"
]

quadrants_arousal = [
    "Q1_1",
    "Q1_2",
    "Q2_1",
    "Q2_2",
    "Q3_1",
    "Q3_2",
    "Q7_1",
    "Q7_2",
    "Q8_1",
    "Q8_2",
    "Q9_1",
    "Q9_2"
]

quadrants_valence = [
    "Q1_1",
    "Q1_2",
    "Q3_1",
    "Q3_2",
    "Q4_1",
    "Q4_2",
    "Q6_1",
    "Q6_2",
    "Q7_1",
    "Q7_2",
    "Q9_1",
    "Q9_2"
]

quadrants_5q = [
    "Q1_1",
    "Q1_2",
    "Q3_1",
    "Q3_2",
    "Q5_1",
    "Q5_2",
    "Q7_1",
    "Q7_2",
    "Q9_1",
    "Q9_2"
]


quadrants_4q = [
    "Q1_1",
    "Q1_2",
    "Q3_1",
    "Q3_2",
    "Q7_1",
    "Q7_2",
    "Q9_1",
    "Q9_2"
]

# %%
quadrants = quadrants_4q

# %%
report, matrix, f1_scores = getmodelresults(create_timestamps(window_sizes), quadrants)
# Out:
# Computing Features for Patient_61...
# Dataset shape: (480, 17)
# (array(['Q1', 'Q3', 'Q7', 'Q9'], dtype='<U2'), array([120, 120, 120, 120], dtype=int64))
# Example of data: AU01_r_mean    0.421570
# AU02_r_mean    0.077438
# AU04_r_mean    0.580826
# AU05_r_mean    0.021570
# AU06_r_mean    0.729917
# AU07_r_mean    0.674050
# AU09_r_mean    0.146364
# AU10_r_mean    1.428843
# AU12_r_mean    0.903471
# AU14_r_mean    0.951653
# AU15_r_mean    0.107025
# AU17_r_mean    0.269421
# AU20_r_mean    0.088430
# AU23_r_mean    0.170909
# AU25_r_mean    0.317190
# AU26_r_mean    0.272893
# AU45_r_mean    0.290826
# Name: 0, dtype: float64
# Class distribution: Counter({'Q1': 120, 'Q3': 120, 'Q7': 120, 'Q9': 120})
# Fold 0
# Train dist: Counter({'Q1': 96, 'Q3': 96, 'Q7': 96, 'Q9': 96})
# Test dist: Counter({'Q1': 24, 'Q7': 24, 'Q3': 24, 'Q9': 24})
# Score: 0.40625
# Fold 1
# Train dist: Counter({'Q1': 96, 'Q3': 96, 'Q7': 96, 'Q9': 96})
# Test dist: Counter({'Q1': 24, 'Q9': 24, 'Q3': 24, 'Q7': 24})
# Score: 0.3958333333333333
# Fold 2
# Train dist: Counter({'Q1': 96, 'Q3': 96, 'Q7': 96, 'Q9': 96})
# Test dist: Counter({'Q3': 24, 'Q9': 24, 'Q7': 24, 'Q1': 24})
# Score: 0.40625
# Fold 3
# Train dist: Counter({'Q1': 96, 'Q3': 96, 'Q7': 96, 'Q9': 96})
# Test dist: Counter({'Q3': 24, 'Q1': 24, 'Q7': 24, 'Q9': 24})
# Score: 0.40625
# Fold 4
# Train dist: Counter({'Q1': 96, 'Q3': 96, 'Q7': 96, 'Q9': 96})
# Test dist: Counter({'Q7': 24, 'Q1': 24, 'Q9': 24, 'Q3': 24})
# Score: 0.375

# %%
print("F1-Scores:", [f"{score:.2f}" for score in f1_scores[:5]])
print()
print(f"Average F1-Score: {sum(f1_scores)/5}")
print()
for idx in range(5):
    print(report[idx])
    print(matrix[idx])
    print()
    print("-"*50)
# Out:
# F1-Scores: ['0.40', '0.39', '0.40', '0.41', '0.37']
#
# Average F1-Score: 0.3959679435519535
#
#               precision    recall  f1-score   support
#
#           Q1       0.25      0.21      0.23        24
#           Q3       0.59      0.54      0.57        24
#           Q7       0.28      0.29      0.29        24
#           Q9       0.48      0.58      0.53        24
#
#     accuracy                           0.41        96
#    macro avg       0.40      0.41      0.40        96
# weighted avg       0.40      0.41      0.40        96
#
# [[ 5  7  8  4]
#  [ 5 13  2  4]
#  [ 8  2  7  7]
#  [ 2  0  8 14]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#           Q1       0.50      0.46      0.48        24
#           Q3       0.56      0.62      0.59        24
#           Q7       0.26      0.29      0.27        24
#           Q9       0.25      0.21      0.23        24
#
#     accuracy                           0.40        96
#    macro avg       0.39      0.40      0.39        96
# weighted avg       0.39      0.40      0.39        96
#
# [[11  3  7  3]
#  [ 4 15  4  1]
#  [ 3  3  7 11]
#  [ 4  6  9  5]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#           Q1       0.38      0.46      0.42        24
#           Q3       0.53      0.42      0.47        24
#           Q7       0.30      0.25      0.27        24
#           Q9       0.43      0.50      0.46        24
#
#     accuracy                           0.41        96
#    macro avg       0.41      0.41      0.40        96
# weighted avg       0.41      0.41      0.40        96
#
# [[11  6  2  5]
#  [ 8 10  5  1]
#  [ 5  3  6 10]
#  [ 5  0  7 12]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#           Q1       0.36      0.33      0.35        24
#           Q3       0.71      0.50      0.59        24
#           Q7       0.31      0.42      0.36        24
#           Q9       0.36      0.38      0.37        24
#
#     accuracy                           0.41        96
#    macro avg       0.44      0.41      0.41        96
# weighted avg       0.44      0.41      0.41        96
#
# [[ 8  3  5  8]
#  [ 7 12  5  0]
#  [ 6  0 10  8]
#  [ 1  2 12  9]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#           Q1       0.41      0.29      0.34        24
#           Q3       0.55      0.25      0.34        24
#           Q7       0.28      0.38      0.32        24
#           Q9       0.39      0.58      0.47        24
#
#     accuracy                           0.38        96
#    macro avg       0.41      0.38      0.37        96
# weighted avg       0.41      0.38      0.37        96
#
# [[ 7  3  8  6]
#  [ 5  6  7  6]
#  [ 3  2  9 10]
#  [ 2  0  8 14]]
#
# --------------------------------------------------

# %%
results.append((f1_scores, common_window_size))

# %%
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt

grouped = defaultdict(list)

for f1, win_size in results:
    grouped[win_size].append(f1)

window_sizes = sorted(grouped.keys())
f1_lists = [np.array(grouped[w]).ravel() for w in window_sizes]

plt.figure()

plt.boxplot(
    f1_lists,
    positions=window_sizes,
    widths=0.1
)

plt.xlabel("Window Size (s)")
plt.ylabel("F1-score")
plt.title("F1-score Distribution per Window Size")

plt.xticks(window_sizes)      # ensure ticks match window sizes
plt.grid(True)

plt.show()

# %%
# np.save("f1_scores_CUT.npy", np.array(results, dtype=object))

# %%
# a = np.load("f1_scores_CUT.npy", allow_pickle=True)

# for i in a:
#     print(f"Window Size: {i[1]} -> {i[0]}")

# %%
import numpy as np
import matplotlib.pyplot as plt

from Modeling_CUT import getmodelresults

# %%
def get_timestamp(center, window_size):
    return [center - window_size/2, center + window_size/2]

# %%
def create_timestamps(window_sizes):

    class Timestamps:
        Q1_1 = [get_timestamp(12, window_sizes[1, 1])]
        Q1_2 = [get_timestamp(26, window_sizes[1, 2])]

        # Q1_1 = [get_timestamp(10, window_sizes[1, 1])]
        # Q1_2 = [get_timestamp(24, window_sizes[1, 2])]

        Q2_1 = [get_timestamp(6, window_sizes[2, 1])]
        Q2_2 = [get_timestamp(12, window_sizes[2, 2])]

        Q3_1 = [get_timestamp(19, window_sizes[3, 1])]
        Q3_2 = [get_timestamp(40, window_sizes[3, 2])]

        Q4_1 = [get_timestamp(15, window_sizes[4, 1])]
        Q4_2 = [get_timestamp(15, window_sizes[4, 2])]

        Q5_1 = [get_timestamp(15, window_sizes[5, 1])]
        Q5_2 = [get_timestamp(10, window_sizes[5, 2])]

        Q6_1 = [get_timestamp(84, window_sizes[6, 1])]
        Q6_2 = [get_timestamp(15, window_sizes[6, 2])]

        Q7_1 = [get_timestamp(40, window_sizes[7, 1])]
        Q7_2 = [get_timestamp(40, window_sizes[7, 2])]
        
        Q8_1 = [get_timestamp(15, window_sizes[8, 1])]
        Q8_2 = [get_timestamp(12, window_sizes[8, 2])]

        Q9_1 = [get_timestamp(15, window_sizes[9, 1])]
        Q9_2 = [get_timestamp(15, window_sizes[9, 2])]

    return Timestamps

# %%
results = []

# %%
common_window_size = 4
window_sizes = np.ones((9, 2))*common_window_size

# common_window_size = 5
# window_sizes = np.ones((9, 2))*5
# window_sizes[0:2][:] = 3

print(window_sizes)

window_sizes = np.pad(window_sizes, ((1, 0), (1, 0)), mode='constant')

#print(window_sizes)
# Out:
# [[4. 4.]
#  [4. 4.]
#  [4. 4.]
#  [4. 4.]
#  [4. 4.]
#  [4. 4.]
#  [4. 4.]
#  [4. 4.]
#  [4. 4.]]

# %%
quadrants_all = [
    "Q1_1",
    "Q1_2",
    "Q2_1",
    "Q2_2",
    "Q3_1",
    "Q3_2",
    "Q4_1",
    "Q4_2",
    "Q5_1",
    "Q5_2",
    "Q6_1",
    "Q6_2",
    "Q7_1",
    "Q7_2",
    "Q8_1",
    "Q8_2",
    "Q9_1",
    "Q9_2"
]

quadrants_arousal = [
    "Q1_1",
    "Q1_2",
    "Q2_1",
    "Q2_2",
    "Q3_1",
    "Q3_2",
    "Q7_1",
    "Q7_2",
    "Q8_1",
    "Q8_2",
    "Q9_1",
    "Q9_2"
]

quadrants_valence = [
    "Q1_1",
    "Q1_2",
    "Q3_1",
    "Q3_2",
    "Q4_1",
    "Q4_2",
    "Q6_1",
    "Q6_2",
    "Q7_1",
    "Q7_2",
    "Q9_1",
    "Q9_2"
]

quadrants_5q = [
    "Q1_1",
    "Q1_2",
    "Q3_1",
    "Q3_2",
    "Q5_1",
    "Q5_2",
    "Q7_1",
    "Q7_2",
    "Q9_1",
    "Q9_2"
]


quadrants_4q = [
    "Q1_1",
    "Q1_2",
    "Q3_1",
    "Q3_2",
    "Q7_1",
    "Q7_2",
    "Q9_1",
    "Q9_2"
]

# %%
quadrants = quadrants_4q

# %%
report, matrix, f1_scores = getmodelresults(create_timestamps(window_sizes), quadrants)
# Out:
# Computing Features for Patient_61...
# Dataset shape: (480, 51)
# (array(['Q1', 'Q3', 'Q7', 'Q9'], dtype='<U2'), array([120, 120, 120, 120], dtype=int64))
# Example of data: AU01_r_mean    0.277137
# AU01_r_std     0.428254
# AU01_r_max     1.450000
# AU02_r_mean    0.063693
# AU02_r_std     0.152987
# AU02_r_max     0.900000
# AU04_r_mean    0.637759
# AU04_r_std     0.438475
# AU04_r_max     1.570000
# AU05_r_mean    0.015602
# AU05_r_std     0.042551
# AU05_r_max     0.230000
# AU06_r_mean    0.840249
# AU06_r_std     0.410284
# AU06_r_max     1.730000
# AU07_r_mean    0.646846
# AU07_r_std     0.529340
# AU07_r_max     2.100000
# AU09_r_mean    0.157593
# AU09_r_std     0.150721
# AU09_r_max     0.550000
# AU10_r_mean    1.453444
# AU10_r_std     0.196893
# AU10_r_max     2.070000
# AU12_r_mean    1.011826
# AU12_r_std     0.256687
# AU12_r_max     1.640000
# AU14_r_mean    1.020124
# AU14_r_std     0.155624
# AU14_r_max     1.490000
# AU15_r_mean    0.113402
# AU15_r_std     0.118311
# AU15_r_max     0.520000
# AU17_r_mean    0.286183
# AU17_r_std     0.151271
# AU17_r_max     0.670000
# AU20_r_mean    0.090166
# AU20_r_std     0.085352
# AU20_r_max     0.360000
# AU23_r_mean    0.162573
# AU23_r_std     0.146239
# AU23_r_max     0.500000
# AU25_r_mean    0.236266
# AU25_r_std     0.190537
# AU25_r_max     0.790000
# AU26_r_mean    0.206929
# AU26_r_std     0.229595
# AU26_r_max     1.140000
# AU45_r_mean    0.195643
# AU45_r_std     0.363156
# AU45_r_max     1.130000
# Name: 0, dtype: float64
# Class distribution: Counter({'Q1': 120, 'Q3': 120, 'Q7': 120, 'Q9': 120})
# Fold 0
# Train dist: Counter({'Q1': 96, 'Q3': 96, 'Q7': 96, 'Q9': 96})
# Test dist: Counter({'Q1': 24, 'Q7': 24, 'Q3': 24, 'Q9': 24})
# Score: 0.5104166666666666
# Fold 1
# Train dist: Counter({'Q1': 96, 'Q3': 96, 'Q7': 96, 'Q9': 96})
# Test dist: Counter({'Q1': 24, 'Q9': 24, 'Q3': 24, 'Q7': 24})
# Score: 0.375
# Fold 2
# Train dist: Counter({'Q1': 96, 'Q3': 96, 'Q7': 96, 'Q9': 96})
# Test dist: Counter({'Q3': 24, 'Q9': 24, 'Q7': 24, 'Q1': 24})
# Score: 0.4375
# Fold 3
# Train dist: Counter({'Q1': 96, 'Q3': 96, 'Q7': 96, 'Q9': 96})
# Test dist: Counter({'Q3': 24, 'Q1': 24, 'Q7': 24, 'Q9': 24})
# Score: 0.3958333333333333
# Fold 4
# Train dist: Counter({'Q1': 96, 'Q3': 96, 'Q7': 96, 'Q9': 96})
# Test dist: Counter({'Q7': 24, 'Q1': 24, 'Q9': 24, 'Q3': 24})
# Score: 0.3541666666666667

# %%
print("F1-Scores:", [f"{score:.2f}" for score in f1_scores[:5]])
print()
print(f"Average F1-Score: {sum(f1_scores)/5}")
print()
for idx in range(5):
    print(report[idx])
    print(matrix[idx])
    print()
    print("-"*50)
# Out:
# F1-Scores: ['0.50', '0.38', '0.44', '0.40', '0.36']
#
# Average F1-Score: 0.4147400742881618
#
#               precision    recall  f1-score   support
#
#           Q1       0.38      0.25      0.30        24
#           Q3       0.58      0.62      0.60        24
#           Q7       0.50      0.46      0.48        24
#           Q9       0.53      0.71      0.61        24
#
#     accuracy                           0.51        96
#    macro avg       0.50      0.51      0.50        96
# weighted avg       0.50      0.51      0.50        96
#
# [[ 6  9  5  4]
#  [ 5 15  0  4]
#  [ 5  1 11  7]
#  [ 0  1  6 17]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#           Q1       0.38      0.25      0.30        24
#           Q3       0.60      0.50      0.55        24
#           Q7       0.30      0.46      0.36        24
#           Q9       0.30      0.29      0.30        24
#
#     accuracy                           0.38        96
#    macro avg       0.39      0.38      0.38        96
# weighted avg       0.39      0.38      0.38        96
#
# [[ 6  6  8  4]
#  [ 5 12  6  1]
#  [ 1  1 11 11]
#  [ 4  1 12  7]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#           Q1       0.46      0.50      0.48        24
#           Q3       0.58      0.46      0.51        24
#           Q7       0.33      0.42      0.37        24
#           Q9       0.43      0.38      0.40        24
#
#     accuracy                           0.44        96
#    macro avg       0.45      0.44      0.44        96
# weighted avg       0.45      0.44      0.44        96
#
# [[12  4  6  2]
#  [ 6 11  5  2]
#  [ 4  2 10  8]
#  [ 4  2  9  9]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#           Q1       0.42      0.33      0.37        24
#           Q3       0.59      0.54      0.57        24
#           Q7       0.24      0.25      0.24        24
#           Q9       0.37      0.46      0.41        24
#
#     accuracy                           0.40        96
#    macro avg       0.40      0.40      0.40        96
# weighted avg       0.40      0.40      0.40        96
#
# [[ 8  7  4  5]
#  [ 5 13  6  0]
#  [ 2  2  6 14]
#  [ 4  0  9 11]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#           Q1       0.41      0.29      0.34        24
#           Q3       0.62      0.42      0.50        24
#           Q7       0.26      0.33      0.29        24
#           Q9       0.28      0.38      0.32        24
#
#     accuracy                           0.35        96
#    macro avg       0.39      0.35      0.36        96
# weighted avg       0.39      0.35      0.36        96
#
# [[ 7  5  8  4]
#  [ 6 10  2  6]
#  [ 2  1  8 13]
#  [ 2  0 13  9]]
#
# --------------------------------------------------

# %%
results.append((f1_scores, common_window_size))

# %%
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt

grouped = defaultdict(list)

for f1, win_size in results:
    grouped[win_size].append(f1)

window_sizes = sorted(grouped.keys())
f1_lists = [np.array(grouped[w]).ravel() for w in window_sizes]

plt.figure()

plt.boxplot(
    f1_lists,
    positions=window_sizes,
    widths=0.1
)

plt.xlabel("Window Size (s)")
plt.ylabel("F1-score")
plt.title("F1-score Distribution per Window Size")

plt.xticks(window_sizes)      # ensure ticks match window sizes
plt.grid(True)

plt.show()

# %%
# np.save("f1_scores_CUT.npy", np.array(results, dtype=object))

# %%
# a = np.load("f1_scores_CUT.npy", allow_pickle=True)

# for i in a:
#     print(f"Window Size: {i[1]} -> {i[0]}")

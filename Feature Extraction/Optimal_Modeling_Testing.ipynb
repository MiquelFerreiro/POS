# %%
# from Modeling import getmodelresults
from Modeling_2 import getmodelresults

# %%
class Timestamps_5s:
    Q1_1 = [[9, 14]]
    Q1_2 = [[24, 29]]

    Q2_1 = [[1, 6],[6, 11]]
    Q2_2 = [[7, 12], [12, 17]]

    Q3_1 = [[14, 19], [19, 24]]
    Q3_2 = [[34, 39], [40, 45], [45, 50]]

    Q4_1 = [[9, 14], [16, 21]]
    Q4_2 = [[10, 15], [16, 21]]

    Q5_1 = [[18, 23], [10, 15]]
    Q5_2 = [[13, 18], [5, 10]]

    Q6_1 = [[80, 85], [85, 90]]
    Q6_2 = [[10, 15], [18, 23]]

    Q7_1 = [[43, 48], [30, 35]]
    Q7_2 = [[36, 41], [41, 46]]

    Q8_1 = [[12, 17], [17, 22]]
    Q8_2 = [[7, 12], [12, 17]]

    Q9_1 = [[15, 20]]
    Q9_2 = [[13, 18]]

class Timestamps_8s:
    Q1_1 = [[9, 17]]
    Q1_2 = [[24, 32]]

    Q9_1 = [[15, 23]]
    Q9_2 = [[13, 21]]

class Timestamps_3s:
    Q1_1 = [[9, 12]]
    Q1_2 = [[24, 27]]

    Q9_1 = [[15, 18]]
    Q9_2 = [[13, 6]]

# %%
def get_timestamp(center, window_size):
    return [center - window_size/2, center + window_size/2]

# %%
def create_timestamps(window_sizes):

    class Timestamps:
        Q1_1 = [get_timestamp(12, window_sizes[1, 1])]
        Q1_2 = [get_timestamp(26, window_sizes[1, 2])]

        # Q1_1 = [get_timestamp(10, window_sizes[1, 1])]
        # Q1_2 = [get_timestamp(24, window_sizes[1, 2])]

        Q2_1 = [get_timestamp(6, window_sizes[2, 1])]
        Q2_2 = [get_timestamp(12, window_sizes[2, 2])]

        Q3_1 = [get_timestamp(19, window_sizes[3, 1])]
        Q3_2 = [get_timestamp(40, window_sizes[3, 2])]

        Q4_1 = [get_timestamp(15, window_sizes[4, 1])]
        Q4_2 = [get_timestamp(15, window_sizes[4, 2])]

        Q5_1 = [get_timestamp(15, window_sizes[5, 1])]
        Q5_2 = [get_timestamp(10, window_sizes[5, 2])]

        Q6_1 = [get_timestamp(84, window_sizes[6, 1])]
        Q6_2 = [get_timestamp(15, window_sizes[6, 2])]

        Q7_1 = [get_timestamp(40, window_sizes[7, 1])]
        Q7_2 = [get_timestamp(40, window_sizes[7, 2])]
        
        Q8_1 = [get_timestamp(15, window_sizes[8, 1])]
        Q8_2 = [get_timestamp(12, window_sizes[8, 2])]

        Q9_1 = [get_timestamp(15, window_sizes[9, 1])]
        Q9_2 = [get_timestamp(15, window_sizes[9, 2])]

    return Timestamps

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
results = []

# %%
paths = [
    "Q1_1",
    "Q1_2",
    "Q2_1",
    "Q2_2",
    "Q3_1",
    "Q3_2",
    "Q4_1",
    "Q4_2",
    "Q5_1",
    "Q5_2",
    "Q6_1",
    "Q6_2",
    "Q7_1",
    "Q7_2",
    "Q8_1",
    "Q8_2",
    "Q9_1",
    "Q9_2"
]

common_window_size = 6
window_sizes = np.ones((9, 2))*common_window_size

# common_window_size = 5
# window_sizes = np.ones((9, 2))*5
# window_sizes[0:2][:] = 3

print(window_sizes)

window_sizes = np.pad(window_sizes, ((1, 0), (1, 0)), mode='constant')

#print(window_sizes)
# Out:
# [[6. 6.]
#  [6. 6.]
#  [6. 6.]
#  [6. 6.]
#  [6. 6.]
#  [6. 6.]
#  [6. 6.]
#  [6. 6.]
#  [6. 6.]]

# %%
report, matrix, f1_scores = getmodelresults(create_timestamps(window_sizes), paths)
# Out:
# Skipping Patient_2, Q1_1
# Skipping Patient_52, Q7_2
# Skipping Patient_53, Q4_2
# Loaded 1077 BVP signals
# Failed: Patient_9, Q7_2Patient_9...
# Computing Features for Patient_13...
# c:\Users\mique\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\signal\_spectral_py.py:600: UserWarning: nperseg = 256 is greater than input length  = 216, using nperseg = 216
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# Failed: Patient_14, Q1_2atient_14...
# Failed: Patient_60, Q3_2atient_60...
# Extracted features for 1071 videos..
# Failed: ['Patient_9, Q7_2', 'Patient_14, Q1_2', 'Patient_60, Q3_2']
# Error: Patient 9 Q8_1
# Error: Patient 14 Q2_1
# Error: Patient 60 Q4_1
# (1071, 9) (1071,)
# (array(['Q1: ↑Arousal ↓Val', 'Q2: ↑Arousal -Val', 'Q3: ↑Arousal ↑Val',
#        'Q4: -Arousal ↓Val', 'Q5: -Arousal -Val', 'Q6: -Arousal ↑Val',
#        'Q7: ↓Arousal ↓Val', 'Q8: ↓Arousal -Val', 'Q9: ↓Arousal ↑Val'],
#       dtype='<U17'), array([118, 119, 119, 118, 120, 120, 118, 119, 120], dtype=int64))
# Example of data:  [ 0.0999455  -0.18332095  0.23645538  0.41977634  3.59607695  0.38301308
#  -0.54811811  0.04459992  1.171875  ]
# Class distribution: Counter({'Q5: -Arousal -Val': 120, 'Q6: -Arousal ↑Val': 120, 'Q9: ↓Arousal ↑Val': 120, 'Q2: ↑Arousal -Val': 119, 'Q3: ↑Arousal ↑Val': 119, 'Q8: ↓Arousal -Val': 119, 'Q1: ↑Arousal ↓Val': 118, 'Q4: -Arousal ↓Val': 118, 'Q7: ↓Arousal ↓Val': 118})
# Fold 0
# Train dist: Counter({'Q5: -Arousal -Val': 96, 'Q6: -Arousal ↑Val': 96, 'Q8: ↓Arousal -Val': 96, 'Q9: ↓Arousal ↑Val': 96, 'Q2: ↑Arousal -Val': 95, 'Q3: ↑Arousal ↑Val': 95, 'Q4: -Arousal ↓Val': 95, 'Q1: ↑Arousal ↓Val': 94, 'Q7: ↓Arousal ↓Val': 94})
# Test dist: Counter({'Q2: ↑Arousal -Val': 24, 'Q7: ↓Arousal ↓Val': 24, 'Q9: ↓Arousal ↑Val': 24, 'Q5: -Arousal -Val': 24, 'Q1: ↑Arousal ↓Val': 24, 'Q3: ↑Arousal ↑Val': 24, 'Q6: -Arousal ↑Val': 24, 'Q4: -Arousal ↓Val': 23, 'Q8: ↓Arousal -Val': 23})
# Score: 0.12149532710280374
# Fold 1
# Train dist: Counter({'Q5: -Arousal -Val': 96, 'Q6: -Arousal ↑Val': 96, 'Q9: ↓Arousal ↑Val': 96, 'Q2: ↑Arousal -Val': 95, 'Q3: ↑Arousal ↑Val': 95, 'Q7: ↓Arousal ↓Val': 95, 'Q8: ↓Arousal -Val': 95, 'Q1: ↑Arousal ↓Val': 94, 'Q4: -Arousal ↓Val': 94})
# Test dist: Counter({'Q2: ↑Arousal -Val': 24, 'Q3: ↑Arousal ↑Val': 24, 'Q5: -Arousal -Val': 24, 'Q8: ↓Arousal -Val': 24, 'Q1: ↑Arousal ↓Val': 24, 'Q4: -Arousal ↓Val': 24, 'Q6: -Arousal ↑Val': 24, 'Q9: ↓Arousal ↑Val': 24, 'Q7: ↓Arousal ↓Val': 23})
# Score: 0.09767441860465116
# Fold 2
# Train dist: Counter({'Q5: -Arousal -Val': 96, 'Q6: -Arousal ↑Val': 96, 'Q9: ↓Arousal ↑Val': 96, 'Q2: ↑Arousal -Val': 95, 'Q3: ↑Arousal ↑Val': 95, 'Q7: ↓Arousal ↓Val': 95, 'Q8: ↓Arousal -Val': 95, 'Q1: ↑Arousal ↓Val': 94, 'Q4: -Arousal ↓Val': 94})
# Test dist: Counter({'Q1: ↑Arousal ↓Val': 24, 'Q5: -Arousal -Val': 24, 'Q3: ↑Arousal ↑Val': 24, 'Q6: -Arousal ↑Val': 24, 'Q8: ↓Arousal -Val': 24, 'Q2: ↑Arousal -Val': 24, 'Q4: -Arousal ↓Val': 24, 'Q9: ↓Arousal ↑Val': 24, 'Q7: ↓Arousal ↓Val': 23})
# Score: 0.09302325581395349
# Fold 3
# Train dist: Counter({'Q3: ↑Arousal ↑Val': 96, 'Q5: -Arousal -Val': 96, 'Q6: -Arousal ↑Val': 96, 'Q9: ↓Arousal ↑Val': 96, 'Q1: ↑Arousal ↓Val': 95, 'Q2: ↑Arousal -Val': 95, 'Q8: ↓Arousal -Val': 95, 'Q4: -Arousal ↓Val': 94, 'Q7: ↓Arousal ↓Val': 94})
# Test dist: Counter({'Q6: -Arousal ↑Val': 24, 'Q8: ↓Arousal -Val': 24, 'Q4: -Arousal ↓Val': 24, 'Q9: ↓Arousal ↑Val': 24, 'Q2: ↑Arousal -Val': 24, 'Q5: -Arousal -Val': 24, 'Q7: ↓Arousal ↓Val': 24, 'Q3: ↑Arousal ↑Val': 23, 'Q1: ↑Arousal ↓Val': 23})
# Score: 0.13551401869158877
# Fold 4
# Train dist: Counter({'Q2: ↑Arousal -Val': 96, 'Q5: -Arousal -Val': 96, 'Q6: -Arousal ↑Val': 96, 'Q9: ↓Arousal ↑Val': 96, 'Q1: ↑Arousal ↓Val': 95, 'Q3: ↑Arousal ↑Val': 95, 'Q4: -Arousal ↓Val': 95, 'Q8: ↓Arousal -Val': 95, 'Q7: ↓Arousal ↓Val': 94})
# Test dist: Counter({'Q6: -Arousal ↑Val': 24, 'Q9: ↓Arousal ↑Val': 24, 'Q7: ↓Arousal ↓Val': 24, 'Q3: ↑Arousal ↑Val': 24, 'Q5: -Arousal -Val': 24, 'Q8: ↓Arousal -Val': 24, 'Q1: ↑Arousal ↓Val': 23, 'Q4: -Arousal ↓Val': 23, 'Q2: ↑Arousal -Val': 23})
# Score: 0.107981220657277

# %%
print("F1-Scores:", [f"{score:.2f}" for score in f1_scores[:5]])
print()
print(f"Average F1-Score: {sum(f1_scores)/5}")
print()
for idx in range(5):
    print(report[idx])
    print(matrix[idx])
    print()
    print("-"*50)
# Out:
# F1-Scores: ['0.12', '0.09', '0.09', '0.13', '0.11']
#
# Average F1-Score: 0.10856341699644212
#
#                    precision    recall  f1-score   support
#
# Q1: ↑Arousal ↓Val       0.12      0.12      0.12        24
# Q2: ↑Arousal -Val       0.19      0.25      0.22        24
# Q3: ↑Arousal ↑Val       0.18      0.17      0.17        24
# Q4: -Arousal ↓Val       0.06      0.04      0.05        23
# Q5: -Arousal -Val       0.13      0.08      0.10        24
# Q6: -Arousal ↑Val       0.05      0.04      0.04        24
# Q7: ↓Arousal ↓Val       0.12      0.12      0.12        24
# Q8: ↓Arousal -Val       0.16      0.22      0.18        23
# Q9: ↓Arousal ↑Val       0.04      0.04      0.04        24
#
#          accuracy                           0.12       214
#         macro avg       0.12      0.12      0.12       214
#      weighted avg       0.12      0.12      0.12       214
#
# [[3 4 6 2 2 1 2 2 2]
#  [2 6 1 1 1 2 3 5 3]
#  [2 1 4 2 3 5 4 1 2]
#  [3 3 1 1 2 1 5 6 1]
#  [2 3 2 4 2 2 1 3 5]
#  [5 4 2 1 1 1 3 4 3]
#  [3 3 3 3 1 3 3 3 2]
#  [1 4 0 2 3 1 3 5 4]
#  [4 3 3 2 0 6 2 3 1]]
#
# --------------------------------------------------
#                    precision    recall  f1-score   support
#
# Q1: ↑Arousal ↓Val       0.18      0.17      0.17        24
# Q2: ↑Arousal -Val       0.11      0.17      0.13        24
# Q3: ↑Arousal ↑Val       0.10      0.12      0.11        24
# Q4: -Arousal ↓Val       0.06      0.04      0.05        24
# Q5: -Arousal -Val       0.05      0.04      0.04        24
# Q6: -Arousal ↑Val       0.07      0.04      0.05        24
# Q7: ↓Arousal ↓Val       0.06      0.04      0.05        23
# Q8: ↓Arousal -Val       0.12      0.12      0.12        24
# Q9: ↓Arousal ↑Val       0.10      0.12      0.11        24
#
#          accuracy                           0.10       215
#         macro avg       0.09      0.10      0.09       215
#      weighted avg       0.09      0.10      0.09       215
#
# [[4 8 3 2 2 0 3 1 1]
#  [1 4 6 2 2 3 1 2 3]
#  [1 4 3 1 4 1 2 2 6]
#  [3 5 2 1 4 0 3 3 3]
#  [6 3 0 3 1 2 3 4 2]
#  [1 5 6 1 3 1 2 2 3]
#  [1 2 6 3 2 2 1 4 2]
#  [2 3 3 2 2 2 1 3 6]
#  [3 2 2 1 2 4 2 5 3]]
#
# --------------------------------------------------
#                    precision    recall  f1-score   support
#
# Q1: ↑Arousal ↓Val       0.05      0.04      0.04        24
# Q2: ↑Arousal -Val       0.13      0.12      0.13        24
# Q3: ↑Arousal ↑Val       0.12      0.12      0.12        24
# Q4: -Arousal ↓Val       0.04      0.04      0.04        24
# Q5: -Arousal -Val       0.07      0.08      0.08        24
# Q6: -Arousal ↑Val       0.22      0.25      0.24        24
# Q7: ↓Arousal ↓Val       0.08      0.09      0.08        23
# Q8: ↓Arousal -Val       0.08      0.08      0.08        24
# Q9: ↓Arousal ↑Val       0.00      0.00      0.00        24
#
#          accuracy                           0.09       215
#         macro avg       0.09      0.09      0.09       215
#      weighted avg       0.09      0.09      0.09       215
#
# [[1 2 4 2 4 4 2 5 0]
#  [3 3 1 2 3 0 4 4 4]
#  [2 4 3 5 3 0 4 2 1]
#  [2 2 2 1 3 2 7 1 4]
#  [3 1 3 2 2 5 2 3 3]
#  [2 3 4 3 1 6 1 1 3]
#  [1 3 1 4 5 3 2 2 2]
#  [4 3 1 2 3 5 1 2 3]
#  [3 2 5 2 4 2 2 4 0]]
#
# --------------------------------------------------
#                    precision    recall  f1-score   support
#
# Q1: ↑Arousal ↓Val       0.05      0.04      0.05        23
# Q2: ↑Arousal -Val       0.23      0.25      0.24        24
# Q3: ↑Arousal ↑Val       0.12      0.17      0.14        23
# Q4: -Arousal ↓Val       0.15      0.12      0.14        24
# Q5: -Arousal -Val       0.14      0.12      0.13        24
# Q6: -Arousal ↑Val       0.18      0.12      0.15        24
# Q7: ↓Arousal ↓Val       0.04      0.04      0.04        24
# Q8: ↓Arousal -Val       0.19      0.21      0.20        24
# Q9: ↓Arousal ↑Val       0.12      0.12      0.12        24
#
#          accuracy                           0.14       214
#         macro avg       0.14      0.14      0.13       214
#      weighted avg       0.14      0.14      0.13       214
#
# [[1 5 2 2 3 1 3 1 5]
#  [3 6 2 1 3 3 2 3 1]
#  [4 2 4 2 2 1 2 3 3]
#  [2 2 6 3 4 1 3 2 1]
#  [2 2 3 4 3 3 3 1 3]
#  [3 1 3 2 3 3 2 2 5]
#  [2 1 6 2 2 2 1 6 2]
#  [0 6 3 2 1 2 4 5 1]
#  [3 1 5 2 1 1 5 3 3]]
#
# --------------------------------------------------
#                    precision    recall  f1-score   support
#
# Q1: ↑Arousal ↓Val       0.10      0.09      0.09        23
# Q2: ↑Arousal -Val       0.04      0.04      0.04        23
# Q3: ↑Arousal ↑Val       0.07      0.04      0.05        24
# Q4: -Arousal ↓Val       0.09      0.09      0.09        23
# Q5: -Arousal -Val       0.11      0.12      0.12        24
# Q6: -Arousal ↑Val       0.11      0.17      0.14        24
# Q7: ↓Arousal ↓Val       0.26      0.21      0.23        24
# Q8: ↓Arousal -Val       0.11      0.12      0.12        24
# Q9: ↓Arousal ↑Val       0.10      0.08      0.09        24
#
#          accuracy                           0.11       213
#         macro avg       0.11      0.11      0.11       213
#      weighted avg       0.11      0.11      0.11       213
#
# [[2 1 2 4 5 4 0 2 3]
#  [5 1 3 4 0 4 1 3 2]
#  [4 4 1 1 3 6 0 3 2]
#  [1 4 2 2 4 4 1 1 4]
#  [2 2 3 3 3 3 1 6 1]
#  [0 5 2 0 2 4 3 4 4]
#  [3 2 0 3 3 3 5 4 1]
#  [2 1 0 4 5 3 5 3 1]
#  [1 6 2 2 2 4 3 2 2]]
#
# --------------------------------------------------

# %%
results.append((f1_scores, common_window_size))

# %%
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt

grouped = defaultdict(list)

for f1, win_size in results:
    grouped[win_size].append(f1)

window_sizes = sorted(grouped.keys())
f1_lists = [np.array(grouped[w]).ravel() for w in window_sizes]

plt.figure()

plt.boxplot(
    f1_lists,
    positions=window_sizes,
    widths=0.1
)

plt.xlabel("Window Size (s)")
plt.ylabel("F1-score")
plt.title("F1-score Distribution per Window Size")

plt.xticks(window_sizes)      # ensure ticks match window sizes
plt.grid(True)

plt.show()

# %%
# np.save("f1_scores_4Qs.npy", np.array(results, dtype=object))

# %%
# a = np.load("f1_scores_4Qs.npy", allow_pickle=True)

# for i in a:
#     print(f"Window Size: {i[1]} -> {i[0]}")

# %%
# from Modeling import getmodelresults
from Modeling_2 import getmodelresults

# %%
class Timestamps_5s:
    Q1_1 = [[9, 14]]
    Q1_2 = [[24, 29]]

    Q2_1 = [[1, 6],[6, 11]]
    Q2_2 = [[7, 12], [12, 17]]

    Q3_1 = [[14, 19], [19, 24]]
    Q3_2 = [[34, 39], [40, 45], [45, 50]]

    Q4_1 = [[9, 14], [16, 21]]
    Q4_2 = [[10, 15], [16, 21]]

    Q5_1 = [[18, 23], [10, 15]]
    Q5_2 = [[13, 18], [5, 10]]

    Q6_1 = [[80, 85], [85, 90]]
    Q6_2 = [[10, 15], [18, 23]]

    Q7_1 = [[43, 48], [30, 35]]
    Q7_2 = [[36, 41], [41, 46]]

    Q8_1 = [[12, 17], [17, 22]]
    Q8_2 = [[7, 12], [12, 17]]

    Q9_1 = [[15, 20]]
    Q9_2 = [[13, 18]]

class Timestamps_8s:
    Q1_1 = [[9, 17]]
    Q1_2 = [[24, 32]]

    Q9_1 = [[15, 23]]
    Q9_2 = [[13, 21]]

class Timestamps_3s:
    Q1_1 = [[9, 12]]
    Q1_2 = [[24, 27]]

    Q9_1 = [[15, 18]]
    Q9_2 = [[13, 6]]

# %%
def get_timestamp(center, window_size):
    return [center - window_size/2, center + window_size/2]

# %%
def create_timestamps(window_sizes):

    class Timestamps:
        Q1_1 = [get_timestamp(12, window_sizes[1, 1])]
        Q1_2 = [get_timestamp(26, window_sizes[1, 2])]

        Q2_1 = [get_timestamp(6, window_sizes[2, 1])]
        Q2_2 = [get_timestamp(12, window_sizes[2, 2])]

        Q3_1 = [get_timestamp(19, window_sizes[3, 1])]
        Q3_2 = [get_timestamp(40, window_sizes[3, 2])]

        Q4_1 = [get_timestamp(15, window_sizes[4, 1])]
        Q4_2 = [get_timestamp(15, window_sizes[4, 2])]

        Q5_1 = [get_timestamp(15, window_sizes[5, 1])]
        Q5_2 = [get_timestamp(10, window_sizes[5, 2])]

        Q6_1 = [get_timestamp(84, window_sizes[6, 1])]
        Q6_2 = [get_timestamp(15, window_sizes[6, 2])]

        Q7_1 = [get_timestamp(40, window_sizes[7, 1])]
        Q7_2 = [get_timestamp(40, window_sizes[7, 2])]
        
        Q8_1 = [get_timestamp(15, window_sizes[8, 1])]
        Q8_2 = [get_timestamp(12, window_sizes[8, 2])]

        Q9_1 = [get_timestamp(15, window_sizes[9, 1])]
        Q9_2 = [get_timestamp(15, window_sizes[9, 2])]

    return Timestamps

# %%
import numpy as np

# %%
paths = [
    "Q1_1",
    "Q1_2",
    # "Q2_1",
    # "Q2_2",
    # "Q3_1",
    # "Q3_2",
    # "Q4_1",
    # "Q4_2",
    # "Q5_1",
    # "Q5_2",
    # "Q6_1",
    # "Q6_2",
    # "Q7_1",
    # "Q7_2",
    # "Q8_1",
    # "Q8_2",
    "Q9_1",
    "Q9_2"
]

common_window_size = 10

window_sizes = np.ones((9, 2))*common_window_size

window_sizes = np.pad(window_sizes, ((1, 0), (1, 0)), mode='constant')

# print(window_sizes)

# %%
report, matrix, f1_scores = getmodelresults(create_timestamps(window_sizes), paths)
# Out:
# Skipping Patient_2, Q1_1
# Loaded 239 BVP signals
# Failed: Patient_14, Q1_2atient_14...
# Extracted features for 237 videos...
# Failed: ['Patient_14, Q1_2']
# Error: Patient 14 Q9_1
# (237, 9) (237,)
# (array(['HighArousal', 'LowArousal'], dtype='<U11'), array([118, 119]))
# Example of data:  [ 0.09887356 -0.18933663  0.2304397   0.41977634  5.86558856  0.25662802
#  -0.77686813  0.04165801  1.171875  ]
# Class distribution: Counter({np.str_('LowArousal'): 119, np.str_('HighArousal'): 118})
# Fold 0
# Train dist: Counter({np.str_('LowArousal'): 95, np.str_('HighArousal'): 94})
# Test dist: Counter({np.str_('LowArousal'): 24, np.str_('HighArousal'): 24})
# Score: 0.4791666666666667
# Fold 1
# Train dist: Counter({np.str_('HighArousal'): 95, np.str_('LowArousal'): 95})
# Test dist: Counter({np.str_('LowArousal'): 24, np.str_('HighArousal'): 23})
# Score: 0.3191489361702128
# Fold 2
# Train dist: Counter({np.str_('HighArousal'): 95, np.str_('LowArousal'): 95})
# Test dist: Counter({np.str_('LowArousal'): 24, np.str_('HighArousal'): 23})
# Score: 0.5319148936170213
# Fold 3
# Train dist: Counter({np.str_('LowArousal'): 95, np.str_('HighArousal'): 94})
# Test dist: Counter({np.str_('HighArousal'): 24, np.str_('LowArousal'): 24})
# Score: 0.5
# Fold 4
# Train dist: Counter({np.str_('LowArousal'): 96, np.str_('HighArousal'): 94})
# Test dist: Counter({np.str_('HighArousal'): 24, np.str_('LowArousal'): 23})
# Score: 0.6170212765957447

# %%
print("F1-Scores:", [f"{score:.2f}" for score in f1_scores[:5]])
print()
print(f"Average F1-Score: {sum(f1_scores)/5}")
print()
for idx in range(5):
    print(report[idx])
    print(matrix[idx])
    print()
    print("-"*50)
# Out:
# F1-Scores: ['0.48', '0.31', '0.53', '0.50', '0.62']
#
# Average F1-Score: 0.48759539663015283
#
#               precision    recall  f1-score   support
#
#  HighArousal       0.48      0.46      0.47        24
#   LowArousal       0.48      0.50      0.49        24
#
#     accuracy                           0.48        48
#    macro avg       0.48      0.48      0.48        48
# weighted avg       0.48      0.48      0.48        48
#
# [[11 13]
#  [12 12]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#  HighArousal       0.34      0.43      0.38        23
#   LowArousal       0.28      0.21      0.24        24
#
#     accuracy                           0.32        47
#    macro avg       0.31      0.32      0.31        47
# weighted avg       0.31      0.32      0.31        47
#
# [[10 13]
#  [19  5]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#  HighArousal       0.52      0.52      0.52        23
#   LowArousal       0.54      0.54      0.54        24
#
#     accuracy                           0.53        47
#    macro avg       0.53      0.53      0.53        47
# weighted avg       0.53      0.53      0.53        47
#
# [[12 11]
#  [11 13]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#  HighArousal       0.50      0.46      0.48        24
#   LowArousal       0.50      0.54      0.52        24
#
#     accuracy                           0.50        48
#    macro avg       0.50      0.50      0.50        48
# weighted avg       0.50      0.50      0.50        48
#
# [[11 13]
#  [11 13]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#  HighArousal       0.62      0.62      0.62        24
#   LowArousal       0.61      0.61      0.61        23
#
#     accuracy                           0.62        47
#    macro avg       0.62      0.62      0.62        47
# weighted avg       0.62      0.62      0.62        47
#
# [[15  9]
#  [ 9 14]]
#
# --------------------------------------------------

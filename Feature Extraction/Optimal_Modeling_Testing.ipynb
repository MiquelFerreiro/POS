# %%
# from Modeling import getmodelresults
from Modeling_2 import getmodelresults

# %%
class Timestamps_5s:
    Q1_1 = [[9, 14]]
    Q1_2 = [[24, 29]]

    Q2_1 = [[1, 6],[6, 11]]
    Q2_2 = [[7, 12], [12, 17]]

    Q3_1 = [[14, 19], [19, 24]]
    Q3_2 = [[34, 39], [40, 45], [45, 50]]

    Q4_1 = [[9, 14], [16, 21]]
    Q4_2 = [[10, 15], [16, 21]]

    Q5_1 = [[18, 23], [10, 15]]
    Q5_2 = [[13, 18], [5, 10]]

    Q6_1 = [[80, 85], [85, 90]]
    Q6_2 = [[10, 15], [18, 23]]

    Q7_1 = [[43, 48], [30, 35]]
    Q7_2 = [[36, 41], [41, 46]]

    Q8_1 = [[12, 17], [17, 22]]
    Q8_2 = [[7, 12], [12, 17]]

    Q9_1 = [[15, 20]]
    Q9_2 = [[13, 18]]

class Timestamps_8s:
    Q1_1 = [[9, 17]]
    Q1_2 = [[24, 32]]

    Q9_1 = [[15, 23]]
    Q9_2 = [[13, 21]]

class Timestamps_3s:
    Q1_1 = [[9, 12]]
    Q1_2 = [[24, 27]]

    Q9_1 = [[15, 18]]
    Q9_2 = [[13, 6]]

# %%
def get_timestamp(center, window_size):
    return [center - window_size/2, center + window_size/2]

# %%
def create_timestamps(window_sizes):

    class Timestamps:
        Q1_1 = [get_timestamp(12, window_sizes[1, 1])]
        Q1_2 = [get_timestamp(26, window_sizes[1, 2])]

        Q2_1 = [get_timestamp(6, window_sizes[2, 1])]
        Q2_2 = [get_timestamp(12, window_sizes[2, 2])]

        Q3_1 = [get_timestamp(19, window_sizes[3, 1])]
        Q3_2 = [get_timestamp(40, window_sizes[3, 2])]

        Q4_1 = [get_timestamp(15, window_sizes[4, 1])]
        Q4_2 = [get_timestamp(15, window_sizes[4, 2])]

        Q5_1 = [get_timestamp(15, window_sizes[5, 1])]
        Q5_2 = [get_timestamp(10, window_sizes[5, 2])]

        Q6_1 = [get_timestamp(84, window_sizes[6, 1])]
        Q6_2 = [get_timestamp(15, window_sizes[6, 2])]

        Q7_1 = [get_timestamp(40, window_sizes[7, 1])]
        Q7_2 = [get_timestamp(40, window_sizes[7, 2])]
        
        Q8_1 = [get_timestamp(15, window_sizes[8, 1])]
        Q8_2 = [get_timestamp(12, window_sizes[8, 2])]

        Q9_1 = [get_timestamp(15, window_sizes[9, 1])]
        Q9_2 = [get_timestamp(15, window_sizes[9, 2])]

    return Timestamps

# %%
import numpy as np

# %%
paths = [
    "Q1_1",
    "Q1_2",
    "Q2_1",
    "Q2_2",
    "Q3_1",
    "Q3_2",
    # "Q4_1",
    # "Q4_2",
    # "Q5_1",
    # "Q5_2",
    # "Q6_1",
    # "Q6_2",
    "Q7_1",
    "Q7_2",
    "Q8_1",
    "Q8_2",
    "Q9_1",
    "Q9_2"
]

common_window_size = 5

window_sizes = np.ones((9, 2))*common_window_size

window_sizes = np.pad(window_sizes, ((1, 0), (1, 0)), mode='constant')

# print(window_sizes)

# %%
report, matrix, f1_scores = getmodelresults(create_timestamps(window_sizes), paths)
# Out:
# Skipping Patient_2, Q1_1
# Skipping Patient_52, Q7_2
# Loaded 718 BVP signals
# Failed: Patient_9, Q7_2Patient_9...
# Failed: Patient_14, Q1_2atient_14...
# Failed: Patient_60, Q3_2atient_60...
# Extracted features for 712 videos...
# Failed: ['Patient_9, Q7_2', 'Patient_14, Q1_2', 'Patient_60, Q3_2']
# Error: Patient 9 Q8_1
# Error: Patient 14 Q2_1
# Error: Patient 60 Q7_1
# (712, 9) (712,)
# (array(['HighArousal', 'LowArousal'], dtype='<U11'), array([237, 475]))
# Example of data:  [ 0.10284795 -0.19216108  0.22761526  0.41977634  3.17331032  0.28735862
#  -0.70757378  0.04706975  1.171875  ]
# Class distribution: Counter({np.str_('LowArousal'): 475, np.str_('HighArousal'): 237})
# Fold 0
# Train dist: Counter({np.str_('LowArousal'): 380, np.str_('HighArousal'): 190})
# Test dist: Counter({np.str_('LowArousal'): 95, np.str_('HighArousal'): 47})
# Score: 0.5774647887323944
# Fold 1
# Train dist: Counter({np.str_('LowArousal'): 380, np.str_('HighArousal'): 189})
# Test dist: Counter({np.str_('LowArousal'): 95, np.str_('HighArousal'): 48})
# Score: 0.6503496503496503
# Fold 2
# Train dist: Counter({np.str_('LowArousal'): 380, np.str_('HighArousal'): 189})
# Test dist: Counter({np.str_('LowArousal'): 95, np.str_('HighArousal'): 48})
# Score: 0.5874125874125874
# Fold 3
# Train dist: Counter({np.str_('LowArousal'): 380, np.str_('HighArousal'): 190})
# Test dist: Counter({np.str_('LowArousal'): 95, np.str_('HighArousal'): 47})
# Score: 0.6267605633802817
# Fold 4
# Train dist: Counter({np.str_('LowArousal'): 380, np.str_('HighArousal'): 190})
# Test dist: Counter({np.str_('LowArousal'): 95, np.str_('HighArousal'): 47})
# Score: 0.6267605633802817

# %%
print("F1-Scores:", [f"{score:.2f}" for score in f1_scores[:5]])
print()
print(f"Average F1-Score: {sum(f1_scores)/5}")
print()
for idx in range(5):
    print(report[idx])
    print(matrix[idx])
    print()
    print("-"*50)
# Out:
# F1-Scores: ['0.42', '0.55', '0.41', '0.50', '0.46']
#
# Average F1-Score: 0.4692824662510269
#
#               precision    recall  f1-score   support
#
#  HighArousal       0.19      0.09      0.12        47
#   LowArousal       0.64      0.82      0.72        95
#
#     accuracy                           0.58       142
#    macro avg       0.42      0.45      0.42       142
# weighted avg       0.49      0.58      0.52       142
#
# [[ 4 43]
#  [17 78]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#  HighArousal       0.46      0.27      0.34        48
#   LowArousal       0.70      0.84      0.76        95
#
#     accuracy                           0.65       143
#    macro avg       0.58      0.56      0.55       143
# weighted avg       0.62      0.65      0.62       143
#
# [[13 35]
#  [15 80]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#  HighArousal       0.18      0.06      0.09        48
#   LowArousal       0.64      0.85      0.73        95
#
#     accuracy                           0.59       143
#    macro avg       0.41      0.46      0.41       143
# weighted avg       0.49      0.59      0.52       143
#
# [[ 3 45]
#  [14 81]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#  HighArousal       0.38      0.19      0.25        47
#   LowArousal       0.68      0.84      0.75        95
#
#     accuracy                           0.63       142
#    macro avg       0.53      0.52      0.50       142
# weighted avg       0.58      0.63      0.59       142
#
# [[ 9 38]
#  [15 80]]
#
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#  HighArousal       0.31      0.11      0.16        47
#   LowArousal       0.67      0.88      0.76        95
#
#     accuracy                           0.63       142
#    macro avg       0.49      0.50      0.46       142
# weighted avg       0.55      0.63      0.56       142
#
# [[ 5 42]
#  [11 84]]
#
# --------------------------------------------------
